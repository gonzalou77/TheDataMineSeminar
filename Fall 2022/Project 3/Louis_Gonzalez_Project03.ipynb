# %% [markdown]
# # Project 3 -- [Louis] [Gonzalez]

# %% [markdown]
# **Internet Sources:**
#
# - To import images into questions 2-4: https://the-examples-book.com/projects/current-projects/30100-2022-project03
# - Using Sphinx and reStructuredText: https://www.sphinx-doc.org/en/master/usage/restructuredtext/basics.html
# - The rest of the homework was completed using the code and materials under TDM 30100 Project 3

# %% [markdown]
# ## Question 1

# %%
# %%bash
#
# cd $HOME/project03
# python3 -m sphinx.cmd.quickstart ./docs -q -p project03 -a "Louis Gonzalez" -v 1.0.0 --sep
# Out:
# Error: specified path is not a directory, or sphinx files already exist.
# sphinx-quickstart only generate into a empty directory. Please specify a new root path.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Input In [73], in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('bash', '', '\ncd $HOME/project03\npython3 -m sphinx.cmd.quickstart ./docs -q -p project03 -a "Louis Gonzalez" -v 1.0.0 --sep\n')
#
# File /usr/local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2358, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2356 with self.builtin_trap:
#    2357     args = (magic_arg_s, cell)
# -> 2358     result = fn(*args, **kwargs)
#    2359 return result
#
# File /usr/local/lib/python3.10/site-packages/IPython/core/magics/script.py:153, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     151 else:
# ...

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Question 2

# %%
# %%bash
#
# cd $HOME/project03/docs
# make html
# Out:
# Running Sphinx v4.5.0
# loading pickled environment... done
# building [mo]: targets for 0 po files that are out of date
# building [html]: targets for 2 source files that are out of date
# updating environment: 0 added, 2 changed, 0 removed
# reading sources... [ 50%] .ipynb_checkpoints/README-checkpoint
# reading sources... [100%] README
# /home/x-gonza533/project03/docs/source/.ipynb_checkpoints/README-checkpoint.rst:46: WARNING: image file not readable: .ipynb_checkpoints/Figure_2.png
# looking for now-outdated files... none found
# pickling environment... done
# /home/x-gonza533/project03/docs/source/.ipynb_checkpoints/README-checkpoint.rst: WARNING: document isn't included in any toctree
# /home/x-gonza533/project03/docs/source/.ipynb_checkpoints/index-checkpoint.rst: WARNING: document isn't included in any toctree
# checking consistency... done
# preparing documents... done
# writing output... [ 33%] .ipynb_checkpoints/README-checkpoint
# writing output... [ 66%] README
# ...

# %%
from IPython import display
display.Image("Question_2_Results1.PNG")

# %%
display.Image("Question_2_Results2.PNG")

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Question 3

# %%
# %%bash
# cd $HOME/project03/docs
# make html
# Out:
# Running Sphinx v4.5.0
# loading pickled environment... done
# building [mo]: targets for 0 po files that are out of date
# building [html]: targets for 0 source files that are out of date
# updating environment: 0 added, 1 changed, 0 removed
# reading sources... [100%] .ipynb_checkpoints/index-checkpoint
# /home/x-gonza533/project03/Louis_Gonzalez_Project03.py:docstring of Louis_Gonzalez_Project03:1: WARNING: duplicate object description of Louis_Gonzalez_Project03, other instance in index, use :noindex: for one of them
# /home/x-gonza533/project03/Louis_Gonzalez_Project03.py:docstring of Louis_Gonzalez_Project03.get_records_for_date:1: WARNING: duplicate object description of Louis_Gonzalez_Project03.get_records_for_date, other instance in index, use :noindex: for one of them
# /home/x-gonza533/project03/Louis_Gonzalez_Project03.py:docstring of Louis_Gonzalez_Project03.get_records_for_date:4: ERROR: Unexpected indentation.
# ...

# %%
from IPython import display
display.Image("Question_3_Results.PNG")

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Question 4

# %%
# %%bash
# cd $HOME/project03/docs
# make html
# Out:
# Running Sphinx v4.5.0
# loading pickled environment... done
# building [mo]: targets for 0 po files that are out of date
# building [html]: targets for 0 source files that are out of date
# updating environment: 0 added, 1 changed, 0 removed
# reading sources... [100%] .ipynb_checkpoints/index-checkpoint
# /home/x-gonza533/project03/Louis_Gonzalez_Project03.py:docstring of Louis_Gonzalez_Project03:1: WARNING: duplicate object description of Louis_Gonzalez_Project03, other instance in index, use :noindex: for one of them
# /home/x-gonza533/project03/Louis_Gonzalez_Project03.py:docstring of Louis_Gonzalez_Project03.get_records_for_date:1: WARNING: duplicate object description of Louis_Gonzalez_Project03.get_records_for_date, other instance in index, use :noindex: for one of them
# /home/x-gonza533/project03/docs/source/.ipynb_checkpoints/index-checkpoint.rst:13: WARNING: toctree contains reference to nonexisting document '.ipynb_checkpoints/README'
# ...

# %%
from IPython import display
display.Image("Question_4_Results.PNG")

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
