# %% [markdown]
# # Project 11 -- Louis Gonzalez

# %% [markdown]
# **Sources:**
# - https://www.youtube.com/watch?v=6V3d3KbfyeU used for Question 5
#
# **Collaboration:** Piazza

# %% [markdown]
# ## Question 1

# %%
display.Image("/home/x-gonza533/Project11/Question_1_1.PNG")

# %%
display.Image("/home/x-gonza533/Project11/Question_1_2.PNG")

# %%
display.Image("/home/x-gonza533/Project11/Question_1_3.PNG")

# %%
display.Image("/home/x-gonza533/Project11/Question_1_4.PNG")

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Question 2

# %% [markdown]
# **Screen Shot of VS Code Installed on My PC**

# %%
from IPython import display
display.Image("/home/x-gonza533/Project11/Question_2.PNG")

# %% [markdown]
# ## Question 3

# %% [markdown]
# # Yes, I was able to get this working.

# %%
display.Image("/home/x-gonza533/Project11/Question_3.PNG")

# %% [markdown]
# ## Question 4

# %%
display.Image("/home/x-gonza533/Project11/Question_4_1.PNG")

# %%
display.Image("/home/x-gonza533/Project11/Question_4_2.PNG")

# %% [markdown]
# ## Question 5

# %% [markdown]
# **Screen Shot of VS Code with Extensions and a Different Theme**
# - I've had VS code for a while already, so I have had this modified for a while but I did add VS code pets and you can have different pets roaming around your VS code space. It is super cute and distracting in all the best ways! It is sort of like owning a fish tank without the work. I show an example of how I changed the theme using the python script developed for Project 07
# - See the bottom left corner to see the pets!

# %%
display.Image("/home/x-gonza533/Project11/Question_5.PNG")

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
