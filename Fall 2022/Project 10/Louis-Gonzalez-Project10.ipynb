# %% [markdown]
# # Project 10 -- Louis Gonzalez

# %% [markdown]
# **TA Help:** None
#
# **Collaboration:** None
#
# **Note:**
#     - Please see Project10TerminalOutput.txt file under each respective question. Q5 is the only question without a terminal input/output

# %% [markdown]
# ## Question 1

# %% [markdown]
# **Please see Project10TerminalOutput.txt file under Question 01**

# %% [markdown]
# ## Question 2

# %%
from IPython import display
display.Image("/home/x-gonza533/Project10/Question_2_1.PNG")

# %%
display.Image("/home/x-gonza533/Project10/Question_2_2.PNG")

# %% [markdown]
# ## Question 3

# %%
display.Image("/home/x-gonza533/Project10/Question_3_1.PNG")

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Question 4

# %%
display.Image("/home/x-gonza533/Project10/Question_4_1.PNG")

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Question 5

# %% [markdown]
# Going through the entire processing of building virtual environment, creating/ building packages,
# uploading, and updated packages on pypi, is there any way to automate this?
#
# It was a very involved and exhausting, but very insightful process that I am appreciative to being exposed to but
# it is quite a lot.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
