# %% [markdown]
# # Project 7 -- Louis Gonzalez

# %% [markdown]
# **TA Help:** John Smith, Alice Jones
# Sources for Q1:
# - https://towardsdatascience.com/4-methods-for-changing-the-column-order-of-a-pandas-data-frame-a16cf0b58943
# - https://www.geeksforgeeks.org/how-to-move-a-column-to-first-position-in-pandas-dataframe/
# - https://pandas.pydata.org/docs/reference/api/pandas.concat.html
# - https://towardsdatascience.com/pca-using-python-scikit-learn-e653f8989e60
# - https://plotly.com/python/pca-visualization/
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html
#
# **Collaboration:** Friend1, Friend2
#
# - Helped figuring out how to load the dataset.
# - Helped debug error with my plot.

# %% [markdown]
# ## Question 1

# %% [markdown]
# **Functions:**
#
# - extract_mz: This functions allows extracted mass spectral metabolomics data in csv file format to be organized and prepared for PCA separation.
# - mz_datastd: This functions allows extracted mass spectral metabolomics data from a data frame to standardized for PCA processing.
# - met_pca: This functions takes the standardized data, performs PCA, and plots the PCA components using plotly, a interactive plotting function

# %% [markdown]
# ## Question 2

# %%
def extract_mz(file_path:str) -> 'pandas.core.frame.DataFrame':
    """
     Given a file path or file name of a csv file in the active working directory, extract_mz will return a
     DataFrame organized with mz being the set of features
    Args:
        file path: The path or file name to the `.csv` file.

    Returns:
        A sorted (by ascending mz values) DataFrame organized with mz as the columns and Samples as the rows being the set of features.
    
    This functions allows extracted mass spectral metabolomics data to be organized and prepared for PCA separation.
    """ 
    pass
   
   
def mz_datastd(dataframe) -> 'pandas.core.frame.DataFrame':
    """
     Uses a Data Frame organized using function mz_extract.
    Args:
        dataframe: a data frame of organized metabolomics data

    Returns:
        mz_datastd returns 3 outputs
        x_val: standardized data using x components
        y_val: standardized data using y components
        new_df: data fram containing all standardized data organized by mz values as column headers
    
    This functions allows extracted mass spectral metabolomics data from a data frame to be prepared for PCA processing.
    """
    pass

def met_pca(dataframe, std_data, num_comp):
    """
     Uses a Data Frame organized using function mz_extract.
    Args:
        dataframe: dataframe that contains standardized data.
        std_data: standardized data.
        num_comp: number of components
    Returns:
        met_pca returns 3 outputs
        comp_df: data frame with labeled pca scatter matrix data.
        PC: numpy array with pca scatter matrix data.
        plot: plotted pc data with interactiveplot.
        
    This functions takes the standardized data, performs PCA, and plots the PCA components
    """
    pass

# %% [markdown]
# ## Question 3

# %%
# %%bash
#
# cd $HOME/Project07
# python3 -m pytest
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.7, pytest-7.1.2, pluggy-1.0.0
# rootdir: /home/x-gonza533/Project07
# plugins: anyio-3.6.1, dash-2.5.1, hypothesis-6.49.1, datafiles-2.0.1
# collected 6 items
#
# test_project07.py FFF                                                    [ 50%]
# test_project07final.py FFF                                               [100%]
#
# =================================== FAILURES ===================================
# _______________________ test_extract_mz[metabolites.csv] _______________________
#
# csv_file = 'metabolites.csv'
#
#     @pytest.mark.parametrize('csv_file',[('metabolites.csv')])
#     def test_extract_mz(csv_file: str):
#         df = extract_mz(csv_file)
# >       assert len(df.column) == 488
# E       AttributeError: 'NoneType' object has no attribute 'column'
#
# test_project07.py:15: AttributeError
# ...

# %%
# code here

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Question 4

# %%
# %%bash
#
# cd $HOME/Project07
# python3 -m pytest
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.7, pytest-7.1.2, pluggy-1.0.0
# rootdir: /home/x-gonza533/Project07
# plugins: anyio-3.6.1, dash-2.5.1, hypothesis-6.49.1, datafiles-2.0.1
# collected 6 items
#
# test_project07.py FFF                                                    [ 50%]
# test_project07final.py FFF                                               [100%]
#
# =================================== FAILURES ===================================
# _______________________ test_extract_mz[metabolites.csv] _______________________
#
# csv_file = 'metabolites.csv'
#
#     @pytest.mark.parametrize('csv_file',[('metabolites.csv')])
#     def test_extract_mz(csv_file: str):
# >       df = extract_mz(csv_file)
#
# test_project07.py:14:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# file_path = 'metabolites.csv'
#
#     def extract_mz(file_path:str) -> 'pandas.core.frame.DataFrame':
# ...

# %%
# %%bash
#
# cd $HOME/Project07
# python3 -m pytest
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.7, pytest-7.1.2, pluggy-1.0.0
# rootdir: /home/x-gonza533/Project07
# plugins: anyio-3.6.1, dash-2.5.1, hypothesis-6.49.1, datafiles-2.0.1
# collected 6 items
#
# test_project07.py FFF                                                    [ 50%]
# test_project07final.py FFF                                               [100%]
#
# =================================== FAILURES ===================================
# _______________________ test_extract_mz[metabolites.csv] _______________________
#
# csv_file = 'metabolites.csv'
#
#     @pytest.mark.parametrize('csv_file',[('metabolites.csv')])
#     def test_extract_mz(csv_file: str):
# >       df = extract_mz(csv_file)
#
# test_project07.py:14:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# project07.py:27: in extract_mz
#     df = df.pivot(df, values = 'mz')
# ...

# %%
# %%bash
#
# cd $HOME/Project07
# python3 -m pytest
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.7, pytest-7.1.2, pluggy-1.0.0
# rootdir: /home/x-gonza533/Project07
# plugins: anyio-3.6.1, dash-2.5.1, hypothesis-6.49.1, datafiles-2.0.1
# collected 6 items
#
# test_project07.py F..                                                    [ 50%]
# test_project07final.py F..                                               [100%]
#
# =================================== FAILURES ===================================
# _______________________ test_extract_mz[metabolites.csv] _______________________
#
# csv_file = 'metabolites.csv'
#
#     @pytest.mark.parametrize('csv_file',[('metabolites.csv')])
#     def test_extract_mz(csv_file: str):
#         df = extract_mz(csv_file)
# >       assert len(df.column) == 488
#
# test_project07.py:15:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# ...

# %%
# %%bash
#
# cd $HOME/Project07
# python3 -m pytest
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.7, pytest-7.1.2, pluggy-1.0.0
# rootdir: /home/x-gonza533/Project07
# plugins: anyio-3.6.1, dash-2.5.1, hypothesis-6.49.1, datafiles-2.0.1
# collected 6 items
#
# test_project07.py F..                                                    [ 50%]
# test_project07final.py F..                                               [100%]
#
# =================================== FAILURES ===================================
# _______________________ test_extract_mz[metabolites.csv] _______________________
#
# csv_file = 'metabolites.csv'
#
#     @pytest.mark.parametrize('csv_file',[('metabolites.csv')])
#     def test_extract_mz(csv_file: str):
#         df = extract_mz(csv_file)
# >       assert len(df.column) == 488
#
# test_project07.py:15:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# ...

# %%
# %%bash
#
# cd $HOME/Project07
# python3 -m pytest
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.7, pytest-7.1.2, pluggy-1.0.0
# rootdir: /home/x-gonza533/Project07
# plugins: anyio-3.6.1, dash-2.5.1, hypothesis-6.49.1, datafiles-2.0.1
# collected 6 items
#
# test_project07.py F..                                                    [ 50%]
# test_project07final.py F..                                               [100%]
#
# =================================== FAILURES ===================================
# _______________________ test_extract_mz[metabolites.csv] _______________________
#
# csv_file = 'metabolites.csv'
#
#     @pytest.mark.parametrize('csv_file',[('metabolites.csv')])
#     def test_extract_mz(csv_file: str):
#         df = extract_mz(csv_file)
# >       assert len(df.column) == 488
#
# test_project07.py:15:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# ...

# %%
# %%bash
#
# cd $HOME/Project07
# python3 -m pytest
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.7, pytest-7.1.2, pluggy-1.0.0
# rootdir: /home/x-gonza533/Project07
# plugins: anyio-3.6.1, dash-2.5.1, hypothesis-6.49.1, datafiles-2.0.1
# collected 6 items
#
# test_project07.py ...                                                    [ 50%]
# test_project07final.py ...                                               [100%]
#
# =============================== warnings summary ===============================
# ../../../usr/local/lib/python3.10/site-packages/numpy/distutils/ccompiler.py:17
#   /usr/local/lib/python3.10/site-packages/numpy/distutils/ccompiler.py:17: DeprecationWarning: The distutils.sysconfig module is deprecated, use sysconfig instead
#     from distutils.sysconfig import customize_compiler
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ========================= 6 passed, 1 warning in 4.42s =========================

# %% [markdown]
# For this project, the "metabolites.csv" data set was used. The path for this data set is provided below. I copied the data set over to the working directory manually.
#
# Project04/tdm/data/biology/metabolites.csv

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Question 5

# %% [markdown]
# Following the process of TDD, it was a nice switch up compared to what we usually do.
#
# As I designed the tests, I had to go back and look at my data set and the overall goal to determine how to organize my data
# and how the parts of my fuction will interact with the data. This type of development also forced me to consider the end goal of
# or the final function. I wanted to ensure that the final function resulted in a information rich output. Although, this was a
# nice change to the usual workflow, I would not say this is the best method for scripting. I can see how TDD can cause a tunnel-vision
# like approach to coding up function which at time may prevent you from moving past intrinsic issues in the code that might not be
# entirely compatible with the end goal.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
