# %% [markdown]
# # Project 09 -- Louis Gonzalez

# %% [markdown]
# **TA Help:** Dr. Ward and Darren via Piazza
#
# - Help with getting the get_rating function to work and building a package

# %% [markdown]
# ## Question 1

# %% [markdown]
# **Activating the base image**

# %%
from IPython import display
display.Image("/home/x-gonza533/Project09/Question_1_1.PNG")

# %% [markdown]
# **Creating a virtual environment**

# %%
display.Image("/home/x-gonza533/Project09/Question_1_2.PNG")

# %% [markdown]
# **Activating and deactivating a virtual environment**

# %%
display.Image("/home/x-gonza533/Project09/Question_1_3.PNG")

# %% [markdown]
# **Building a new virtual environment and deleting a virtual environment**

# %%
display.Image("/home/x-gonza533/Project09/Question_1_4.PNG")

# %% [markdown]
# ## Question 2

# %% [markdown]
# **Creating virtual environment question02 and installing the necessary packages to run get_rating**

# %%
display.Image("/home/x-gonza533/Project09/Question_2_1.PNG")

# %% [markdown]
# **Running get_rating function**

# %%
display.Image("/home/x-gonza533/Project09/Question_2_2.PNG")

# %% [markdown]
# ## Question 3

# %% [markdown]
# **Running get_rating function successfully**
#
# - I did not realize we needed the other parts where it fails but it did fail in each case in which it was stating the function would fail.

# %%
display.Image("/home/x-gonza533/Project09/Question_3_1.PNG")

# %% [markdown]
# ## Question 4

# %% [markdown]
# **Creating and activating a new virtual environment, and building the package**

# %%
display.Image("/home/x-gonza533/Project09/Question_4_1.PNG")

# %%
display.Image("/home/x-gonza533/Project09/Question_4_2.PNG")

# %% [markdown]
# **Checking the package with twine**

# %%
display.Image("/home/x-gonza533/Project09/Question_4_3.PNG")

# %% [markdown]
# **Uploading the package to testpypi.org**

# %%
display.Image("/home/x-gonza533/Project09/Question_4_4.PNG")

# %% [markdown]
# **I was having issues with the .toml file, so I changed the name of the package to the name of the virtual environment.
# I am certain that this is not the reason it worked but I didn't want to jynx it and have it not work.**

# %%
display.Image("/home/x-gonza533/Project09/Question_4_5.PNG")

# %% [markdown]
# ## Question 5

# %% [markdown]
# **Deactivate old venv, create and activate new one, install twine, and uploading to pypi.org**

# %%
display.Image("/home/x-gonza533/Project09/Question_5_1.PNG")

# %% [markdown]
# **Screenshot of the package on pypi**

# %%
display.Image("/home/x-gonza533/Project09/Question_5_2.PNG")

# %% [markdown]
# **installing the uploaded package and running the get_rating function from the imdb package**

# %%
display.Image("/home/x-gonza533/Project09/Question_5_3.PNG")

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
